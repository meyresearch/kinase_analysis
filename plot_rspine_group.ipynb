# %%
import mdtraj as md
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

from funcs_validate_msm import *
from funcs_sample import *
from paths import *

# %%
ftrajs_rspine = [np.load(file) for file in ftraj_rspine_files]
ftraj = np.concatenate(ftrajs_rspine)

# %%
data = pd.DataFrame(ftraj[::1000, 0:2]*10, columns=['dist(Cg-Leu777, Sd-M766)', 'dist(Cg-Phe856, Sd-M766)'])

# %%
fig, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(data=data, ax=ax, x='dist(Cg-Leu777, Sd-M766)', y='dist(Cg-Phe856, Sd-M766)', cbar=True, fill=True, cmap='Reds', levels=5)
# Out:
# <Axes: xlabel='dist(Cg-Leu777, Sd-M766)', ylabel='dist(Cg-Phe856, Sd-M766)'>

# %%
d1 = [ftraj[:, 0] for ftraj in ftrajs_rspine]
d2 = [ftraj[:, 1] for ftraj in ftrajs_rspine]

rspine_samples_a = sample_frames_by_features([d1,d2], [[0.48, 0.53],[0.6, 0.62]], 20)
rspine_samples_b = sample_frames_by_features([d1,d2], [[0.78, 0.8],[1.15,1.2]], 20)

# %%
save_samples(rspine_samples_a, traj_files, 'data_egfr/samples/rspine_samples_a.pdb')
save_samples(rspine_samples_b, traj_files, 'data_egfr/samples/rspine_samples_b.pdb')
